# %% [markdown]
# <a href="https://colab.research.google.com/github/bguliyeva6868/DataScience/blob/main/Homework5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case Intro
# Term deposits are a major source of income for a bank. A term deposit is a cash investment held at a financial institution. Your money is invested for an agreed rate of interest over a fixed amount of time, or term. The bank has various outreach plans to sell term deposits to their customers such as email marketing, advertisements, telephonic marketing, and digital marketing.
#
# Telephonic marketing campaigns still remain one of the most effective way to reach out to people. However, they require huge investment as large call centers are hired to actually execute these campaigns. Hence, it is crucial to identify the customers most likely to convert beforehand so that they can be specifically targeted via call.
#
# The data is related to direct marketing campaigns (phone calls) of a Portuguese banking institution. The classification goal is to predict if the client will subscribe to a term deposit (variable y).
#
# Content
# The data is related to the direct marketing campaigns of a Portuguese banking institution. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to access if the product (bank term deposit) would be ('yes') or not ('no') subscribed by the customer or not. The data folder contains two datasets:-
#
# Bank.csv: 45,211 rows and 18 columns ordered by date (from May 2008 to November 2010)
#
# Detailed Column Descriptions
# bank client data:
#
# 1 - age (numeric)
#
# 2 - job : type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student",
# "blue-collar","self-employed","retired","technician","services")
#
# 3 - marital : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
#
# 4 - education (categorical: "unknown","secondary","primary","tertiary")
#
# 5 - default: has credit in default? (binary: "yes","no")
#
# 6 - balance: average yearly balance, in euros (numeric)
#
# 7 - housing: has housing loan? (binary: "yes","no")
#
# 8 - loan: has personal loan? (binary: "yes","no")
# # related with the last contact of the current campaign:
# 9 - contact: contact communication type (categorical: "unknown","telephone","cellular")
# 10 - day: last contact day of the month (numeric)
#
# 11 - month: last contact month of year (categorical: "jan", "feb", "mar", …, "nov", "dec")
#
# 12 - duration: last contact duration, in seconds (numeric)
#
# # other attributes:
# 13 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
# 14 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
#
# 15 - previous: number of contacts performed before this campaign and for this client (numeric)
#
# 16 - poutcome: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")
#
# Output variable (desired target):
#
# 17 - y - has the client subscribed a term deposit? (binary: "yes","no")
#
# Missing Attribute Values: None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 0        unknown    5   may       261         1     -1         0  unknown   no
# 1        unknown    5   may       151         1     -1         0  unknown   no
# 2        unknown    5   may        76         1     -1         0  unknown   no
# 3        unknown    5   may        92         1     -1         0  unknown   no
# 4        unknown    5   may       198         1     -1         0  unknown   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
print(df.shape)
df.info()
df.isnull().sum()
# Out:
# (45211, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
#For object check the data 
for cn in df.columns:
  if(df[cn].dtype==object):
    print(df[cn].value_counts())
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64
# married     27214
# single      12790
# divorced     5207
# Name: marital, dtype: int64
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64
# no     44396
# yes      815
# Name: default, dtype: int64
# yes    25130
# no     20081
# Name: housing, dtype: int64
# no     37967
# yes     7244
# Name: loan, dtype: int64
# cellular     29285
# unknown      13020
# telephone     2906
# Name: contact, dtype: int64
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: month, dtype: int64
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: poutcome, dtype: int64
# no     39922
# yes     5289
# Name: y, dtype: int64

# %%
def Encoder(df):
          from sklearn import preprocessing
          columnsToEncode = list(df.select_dtypes(include=['category','object']))
          le = preprocessing.LabelEncoder()
          for feature in columnsToEncode:
              try:
                  df[feature] = le.fit_transform(df[feature])
              except:
                  print('Error encoding '+feature)
          return df

# %%
df=Encoder(df)
df
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    4        1          2        0     2143        1     0        2
# 1       44    9        2          1        0       29        1     0        2
# 2       33    2        1          1        0        2        1     1        2
# 3       47    1        1          3        0     1506        1     0        2
# 4       33   11        2          3        0        1        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    9        1          2        0      825        0     0        0
# 45207   71    5        0          0        0     1729        0     0        0
# 45208   72    5        1          1        0     5715        0     0        0
# 45209   57    1        1          1        0      668        0     0        1
# 45210   37    2        1          1        0     2971        0     0        0
#
#        day  month  duration  campaign  pdays  previous  poutcome  y
# 0        5      8       261         1     -1         0         3  0
# 1        5      8       151         1     -1         0         3  0
# 2        5      8        76         1     -1         0         3  0
# 3        5      8        92         1     -1         0         3  0
# 4        5      8       198         1     -1         0         3  0
# ...    ...    ...       ...       ...    ...       ...       ... ..
# 45206   17      9       977         3     -1         0         3  1
# 45207   17      9       456         2     -1         0         3  1
# 45208   17      9      1127         5    184         3         2  1
# 45209   17      9       508         4     -1         0         3  0
# 45210   17      9       361         2    188        11         1  0
#
# [45211 rows x 17 columns]

# %%
y = df['y'] #Output
X = df.drop('y',axis=1)
X
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    4        1          2        0     2143        1     0        2
# 1       44    9        2          1        0       29        1     0        2
# 2       33    2        1          1        0        2        1     1        2
# 3       47    1        1          3        0     1506        1     0        2
# 4       33   11        2          3        0        1        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    9        1          2        0      825        0     0        0
# 45207   71    5        0          0        0     1729        0     0        0
# 45208   72    5        1          1        0     5715        0     0        0
# 45209   57    1        1          1        0      668        0     0        1
# 45210   37    2        1          1        0     2971        0     0        0
#
#        day  month  duration  campaign  pdays  previous  poutcome
# 0        5      8       261         1     -1         0         3
# 1        5      8       151         1     -1         0         3
# 2        5      8        76         1     -1         0         3
# 3        5      8        92         1     -1         0         3
# 4        5      8       198         1     -1         0         3
# ...    ...    ...       ...       ...    ...       ...       ...
# 45206   17      9       977         3     -1         0         3
# 45207   17      9       456         2     -1         0         3
# 45208   17      9      1127         5    184         3         2
# 45209   17      9       508         4     -1         0         3
# 45210   17      9       361         2    188        11         1
#
# [45211 rows x 16 columns]

# %%
from sklearn.model_selection import  train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)

# %% [markdown]
#
#
#
# Q1)Using  Random Forest,XGBoost, Light GBM and Gradient Boosting Classifier with default parameters (no parameter specifications except random_state) calculate Accuracy on Test data. Which method gives the best accuracy on test data

# %%
#Q1
#Random Forest 
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(random_state=17 )
forest.fit(X_train, y_train)

# make predictions for test data

forest_pred = forest.predict(X_test)
print(accuracy_score(y_test, forest_pred) )
# Out:
# 0.9025037600636999

# %%
# XGBoost
from xgboost import XGBClassifier
model = XGBClassifier(random_state=17)
model.fit(X_train, y_train)
# make predictions for test data
xgb_pred = model.predict(X_test)
print(accuracy_score(y_test, xgb_pred))
# Out:
# 0.90020348580023

# %%
#Light GBM
import lightgbm as lgb
lgb_model = lgb.LGBMClassifier(random_state=17)
lgb_model.fit(X_train, y_train)
# make predictions for test data
print(accuracy_score(y_test, lgb_model.predict(X_test)))
# Out:
# 0.9044501459789437

# %%
#Gradient Boosting
from sklearn.ensemble import GradientBoostingClassifier
gbm_model = GradientBoostingClassifier(random_state=17)
gbm_model.fit(X_train, y_train)
print(accuracy_score(y_test, gbm_model.predict(X_test)))
# Out:
# 0.9018844554543042

# %% [markdown]
# Light GBM gives more accuracy, however the difference is very little (less than 1%)

# %% [markdown]
# Q2) Using optuna hyperparmeter optimization technique and 100 trial
#
#  a)find best methods with  parameters  using Cross validation (CV=3) technique for the range of   parameters below. What are the best parameters for the method with highest cross validation accuracy?
#
# "max_depth": range(2, 16), "max_features": range(2, 16)
#
#  b)Evaluate the performance of the  method with highest cross validation accuracy on test data.What is the accuracy value?

# %%
#Q2
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-2.10.0-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 5.5 MB/s
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.1)
# Collecting cliff
#   Downloading cliff-3.10.1-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 7.7 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.63.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Collecting colorlog
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Collecting alembic
#   Downloading alembic-1.7.7-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 11.7 MB/s
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.32)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.7)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.11.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.4.0)
# Collecting Mako
#   Downloading Mako-1.2.0-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 6.0 MB/s
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.2.0)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.5.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.3 MB/s
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.8.1-py2.py3-none-any.whl (113 kB)
#      |████████████████████████████████| 113 kB 66.3 MB/s
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.0-py3-none-any.whl (29 kB)
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.0-py3-none-any.whl (150 kB)
#      |████████████████████████████████| 150 kB 56.8 MB/s
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.7.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=a274ed68fc9094a90697e23cf722ccc1caf0000f0b563bd2a2e9ea1099680878
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# Installing collected packages: pyperclip, pbr, stevedore, Mako, cmd2, autopage, colorlog, cmaes, cliff, alembic, optuna
# Successfully installed Mako-1.2.0 alembic-1.7.7 autopage-0.5.0 cliff-3.10.1 cmaes-0.8.2 cmd2-2.4.0 colorlog-6.6.0 optuna-2.10.0 pbr-5.8.1 pyperclip-1.8.2 stevedore-3.5.0

# %%
import optuna

import sklearn.datasets
import sklearn.ensemble
import sklearn.model_selection
import sklearn.svm

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)
# FYI: Objective functions can take additional arguments
# (https://optuna.readthedocs.io/en/stable/faq.html#objective-func-additional-args).
def objective(trial):
    x, y = X_train,y_train

    regressor_name = trial.suggest_categorical("regressor", ["GradientBoosting", "XGBoost","LightGBM","RandomForest"])
    if regressor_name == "GradientBoosting":
         max_depth = trial.suggest_int("max_depth",2,16)
         max_features = trial.suggest_int("max_features",2,16)
         regressor_obj = sklearn.ensemble.GradientBoostingRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
    
    elif regressor_name == "XGBoost":
         from xgboost import XGBRegressor
         max_depth = trial.suggest_int("max_depth",2,16)
         max_features = trial.suggest_int("max_features",2,16)
         regressor_obj = XGBRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
        
         

    elif regressor_name == "LightGBM":
         import lightgbm as lgb
         max_depth = trial.suggest_int("max_depth",2,16)
         max_features = trial.suggest_int("max_features",2,16)
         regressor_obj = lgb.LGBMRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
        
       
   
    else:
         max_depth = trial.suggest_int("max_depth",2,16)
         max_features = trial.suggest_int("max_features",2,16)
         regressor_obj = sklearn.ensemble.RandomForestRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )

     

    r2=sklearn.model_selection.cross_val_score(regressor_obj, x, y, n_jobs=-1, cv=3).mean()
   
    return r2


if __name__ == "__main__":
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=100)
    print(study.best_trial)
# Out:
# [I 2022-03-27 20:39:28,134] A new study created in memory with name: no-name-e0a001c8-1053-40ce-b6dd-35a16531e6f3
# [I 2022-03-27 20:39:32,277] Trial 0 finished with value: 0.359339894831263 and parameters: {'regressor': 'LightGBM', 'max_depth': 3, 'max_features': 11}. Best is trial 0 with value: 0.359339894831263.
# [I 2022-03-27 20:40:07,384] Trial 1 finished with value: 0.2877404576643705 and parameters: {'regressor': 'XGBoost', 'max_depth': 14, 'max_features': 6}. Best is trial 0 with value: 0.359339894831263.
# [I 2022-03-27 20:40:15,700] Trial 2 finished with value: 0.3360708215104593 and parameters: {'regressor': 'RandomForest', 'max_depth': 7, 'max_features': 11}. Best is trial 0 with value: 0.359339894831263.
# [I 2022-03-27 20:40:16,853] Trial 3 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 3}. Best is trial 3 with value: 0.3837451601243402.
# [I 2022-03-27 20:40:34,147] Trial 4 finished with value: 0.3623901838280303 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 8, 'max_features': 14}. Best is trial 3 with value: 0.3837451601243402.
# [I 2022-03-27 20:40:44,663] Trial 5 finished with value: 0.3664358933369914 and parameters: {'regressor': 'RandomForest', 'max_depth': 13, 'max_features': 8}. Best is trial 3 with value: 0.3837451601243402.
# [I 2022-03-27 20:41:13,780] Trial 6 finished with value: 0.2764069659439999 and parameters: {'regressor': 'XGBoost', 'max_depth': 16, 'max_features': 11}. Best is trial 3 with value: 0.3837451601243402.
# [I 2022-03-27 20:41:33,295] Trial 7 finished with value: 0.31814052509798746 and parameters: {'regressor': 'XGBoost', 'max_depth': 12, 'max_features': 16}. Best is trial 3 with value: 0.3837451601243402.
# [I 2022-03-27 20:41:39,878] Trial 8 finished with value: 0.2811151805618641 and parameters: {'regressor': 'RandomForest', 'max_depth': 4, 'max_features': 12}. Best is trial 3 with value: 0.3837451601243402.
# [I 2022-03-27 20:41:58,297] Trial 9 finished with value: 0.31814052509798746 and parameters: {'regressor': 'XGBoost', 'max_depth': 12, 'max_features': 12}. Best is trial 3 with value: 0.3837451601243402.
# [I 2022-03-27 20:41:59,493] Trial 10 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 2}. Best is trial 3 with value: 0.3837451601243402.
# [I 2022-03-27 20:42:00,688] Trial 11 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 2}. Best is trial 3 with value: 0.3837451601243402.
# [I 2022-03-27 20:42:01,806] Trial 12 finished with value: 0.38119356678276883 and parameters: {'regressor': 'LightGBM', 'max_depth': 5, 'max_features': 2}. Best is trial 3 with value: 0.3837451601243402.
# [I 2022-03-27 20:42:02,994] Trial 13 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 5}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:04,184] Trial 14 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 5}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:15,720] Trial 15 finished with value: 0.3546233847353573 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 10, 'max_features': 7}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:16,894] Trial 16 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 5}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:18,124] Trial 17 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 5}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:19,320] Trial 18 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 4}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:41,170] Trial 19 finished with value: 0.321790415472009 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 15, 'max_features': 9}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:41,866] Trial 20 finished with value: 0.3285509525098687 and parameters: {'regressor': 'LightGBM', 'max_depth': 2, 'max_features': 9}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:43,035] Trial 21 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 5}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:44,220] Trial 22 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 6}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:45,377] Trial 23 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 4}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:46,551] Trial 24 finished with value: 0.38780396438906567 and parameters: {'regressor': 'LightGBM', 'max_depth': 8, 'max_features': 7}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:47,734] Trial 25 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 4}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:48,888] Trial 26 finished with value: 0.38634580523343964 and parameters: {'regressor': 'LightGBM', 'max_depth': 13, 'max_features': 4}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:56,894] Trial 27 finished with value: 0.3743163896148454 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 8, 'max_features': 6}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:06,238] Trial 28 finished with value: 0.36204450497598567 and parameters: {'regressor': 'RandomForest', 'max_depth': 11, 'max_features': 8}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:07,302] Trial 29 finished with value: 0.3882812159412718 and parameters: {'regressor': 'LightGBM', 'max_depth': 12, 'max_features': 3}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:08,501] Trial 30 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 3}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:09,662] Trial 31 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 5}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:10,825] Trial 32 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 5}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:12,020] Trial 33 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 7}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:13,176] Trial 34 finished with value: 0.38680737289053396 and parameters: {'regressor': 'LightGBM', 'max_depth': 14, 'max_features': 6}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:25,405] Trial 35 finished with value: 0.354964505140277 and parameters: {'regressor': 'XGBoost', 'max_depth': 9, 'max_features': 4}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:30,015] Trial 36 finished with value: 0.3485468445674081 and parameters: {'regressor': 'RandomForest', 'max_depth': 11, 'max_features': 3}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:31,219] Trial 37 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 10}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:48,221] Trial 38 finished with value: 0.3315469502015229 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 13, 'max_features': 8}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:49,425] Trial 39 finished with value: 0.38780396438906567 and parameters: {'regressor': 'LightGBM', 'max_depth': 8, 'max_features': 5}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:07,733] Trial 40 finished with value: 0.31814052509798746 and parameters: {'regressor': 'XGBoost', 'max_depth': 12, 'max_features': 7}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:08,904] Trial 41 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 6}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:10,064] Trial 42 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 6}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:11,245] Trial 43 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 4}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:17,555] Trial 44 finished with value: 0.36227915590047255 and parameters: {'regressor': 'RandomForest', 'max_depth': 11, 'max_features': 5}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:18,745] Trial 45 finished with value: 0.3882812159412718 and parameters: {'regressor': 'LightGBM', 'max_depth': 12, 'max_features': 6}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:20,091] Trial 46 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 14}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:21,441] Trial 47 finished with value: 0.38780396438906567 and parameters: {'regressor': 'LightGBM', 'max_depth': 8, 'max_features': 14}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:34,909] Trial 48 finished with value: 0.354964505140277 and parameters: {'regressor': 'XGBoost', 'max_depth': 9, 'max_features': 3}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:36,125] Trial 49 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 16}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:37,318] Trial 50 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 14}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:38,529] Trial 51 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 15}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:39,714] Trial 52 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 12}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:40,886] Trial 53 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 15}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:42,073] Trial 54 finished with value: 0.3882812159412718 and parameters: {'regressor': 'LightGBM', 'max_depth': 12, 'max_features': 13}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:53,214] Trial 55 finished with value: 0.3487265834273641 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 11, 'max_features': 6}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:54,393] Trial 56 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 13}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:57,229] Trial 57 finished with value: 0.29516591773711487 and parameters: {'regressor': 'RandomForest', 'max_depth': 8, 'max_features': 2}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:58,435] Trial 58 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 10}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:59,604] Trial 59 finished with value: 0.38680737289053396 and parameters: {'regressor': 'LightGBM', 'max_depth': 14, 'max_features': 10}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:00,794] Trial 60 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 10}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:01,983] Trial 61 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 5}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:03,193] Trial 62 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 5}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:04,347] Trial 63 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 5}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:05,528] Trial 64 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 4}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:06,717] Trial 65 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 15}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:07,901] Trial 66 finished with value: 0.38634580523343964 and parameters: {'regressor': 'LightGBM', 'max_depth': 13, 'max_features': 15}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:20,082] Trial 67 finished with value: 0.354964505140277 and parameters: {'regressor': 'XGBoost', 'max_depth': 9, 'max_features': 7}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:27,848] Trial 68 finished with value: 0.36747944170084795 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 4, 'max_features': 12}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:29,050] Trial 69 finished with value: 0.38780396438906567 and parameters: {'regressor': 'LightGBM', 'max_depth': 8, 'max_features': 4}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:30,275] Trial 70 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 13}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:31,466] Trial 71 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 13}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:32,661] Trial 72 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 13}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:33,832] Trial 73 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 5}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:35,035] Trial 74 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 4}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:36,222] Trial 75 finished with value: 0.3882812159412718 and parameters: {'regressor': 'LightGBM', 'max_depth': 12, 'max_features': 16}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:40,804] Trial 76 finished with value: 0.3485468445674081 and parameters: {'regressor': 'RandomForest', 'max_depth': 11, 'max_features': 3}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:42,049] Trial 77 finished with value: 0.38780396438906567 and parameters: {'regressor': 'LightGBM', 'max_depth': 8, 'max_features': 6}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:43,233] Trial 78 finished with value: 0.3882812159412718 and parameters: {'regressor': 'LightGBM', 'max_depth': 12, 'max_features': 3}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:44,442] Trial 79 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 15}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:58,666] Trial 80 finished with value: 0.34157984387705786 and parameters: {'regressor': 'XGBoost', 'max_depth': 10, 'max_features': 11}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:59,840] Trial 81 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 11}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:01,026] Trial 82 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 13}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:02,242] Trial 83 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 6}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:03,427] Trial 84 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 9}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:04,617] Trial 85 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 12}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:05,797] Trial 86 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 8}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:06,955] Trial 87 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 14}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:08,127] Trial 88 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 7}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:27,403] Trial 89 finished with value: 0.3514681931251082 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 9, 'max_features': 14}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:33,108] Trial 90 finished with value: 0.3454181091736935 and parameters: {'regressor': 'RandomForest', 'max_depth': 8, 'max_features': 6}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:34,296] Trial 91 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 12}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:35,488] Trial 92 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 4}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:36,668] Trial 93 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 14}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:37,864] Trial 94 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 4}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:39,091] Trial 95 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 15}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:40,271] Trial 96 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 15}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:41,467] Trial 97 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 9}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:42,665] Trial 98 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 8}. Best is trial 13 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:43,864] Trial 99 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 13}. Best is trial 13 with value: 0.3892534050390631.
# FrozenTrial(number=13, values=[0.3892534050390631], datetime_start=datetime.datetime(2022, 3, 27, 20, 42, 1, 808535), datetime_complete=datetime.datetime(2022, 3, 27, 20, 42, 2, 993583), params={'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 5}, distributions={'regressor': CategoricalDistribution(choices=('GradientBoosting', 'XGBoost', 'LightGBM', 'RandomForest')), 'max_depth': IntUniformDistribution(high=16, low=2, step=1), 'max_features': IntUniformDistribution(high=16, low=2, step=1)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=13, state=TrialState.COMPLETE, value=None)

# %%
print(study.best_params)
# Out:
# {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 5}

# %%
import lightgbm as lgb
lgb_model = lgb.LGBMClassifier(random_state=17,max_depth=10,max_features=11)
lgb_model.fit(X_train, y_train)
# make predictions for test data
print(accuracy_score(y_test, lgb_model.predict(X_test)))
# Out:
# 0.905511811023622

# %% [markdown]
# For Q3 and Q4 ,use the following data.

# %%
dr=pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv')
dr
# Out:
#       Carat Weight              Cut Color Clarity Polish Symmetry Report  \
# 0             1.10            Ideal     H     SI1     VG       EX    GIA
# 1             0.83            Ideal     H     VS1     ID       ID   AGSL
# 2             0.85            Ideal     H     SI1     EX       EX    GIA
# 3             0.91            Ideal     E     SI1     VG       VG    GIA
# 4             0.83            Ideal     G     SI1     EX       EX    GIA
# ...            ...              ...   ...     ...    ...      ...    ...
# 5995          1.03            Ideal     D     SI1     EX       EX    GIA
# 5996          1.00        Very Good     D     SI1     VG       VG    GIA
# 5997          1.02            Ideal     D     SI1     EX       EX    GIA
# 5998          1.27  Signature-Ideal     G     VS1     EX       EX    GIA
# 5999          2.19            Ideal     E     VS1     EX       EX    GIA
#
#       Price
# 0      5169
# 1      3470
# 2      3183
# 3      4370
# 4      3171
# ...     ...
# 5995   6250
# 5996   5328
# 5997   6157
# 5998  11206
# 5999  30507
#
# [6000 rows x 8 columns]

# %%
def Encoder(df):
          from sklearn import preprocessing
          columnsToEncode = list(df.select_dtypes(include=['category','object']))
          le = preprocessing.LabelEncoder()
          for feature in columnsToEncode:
              try:
                  df[feature] = le.fit_transform(df[feature])
              except:
                  print('Error encoding '+feature)
          return df

# %%
dr=Encoder(dr)
dr
# Out:
#       Carat Weight  Cut  Color  Clarity  Polish  Symmetry  Report  Price
# 0             1.10    2      4        2       3         0       1   5169
# 1             0.83    2      4        3       2         2       0   3470
# 2             0.85    2      4        2       0         0       1   3183
# 3             0.91    2      1        2       3         3       1   4370
# 4             0.83    2      3        2       0         0       1   3171
# ...            ...  ...    ...      ...     ...       ...     ...    ...
# 5995          1.03    2      0        2       0         0       1   6250
# 5996          1.00    4      0        2       3         3       1   5328
# 5997          1.02    2      0        2       0         0       1   6157
# 5998          1.27    3      3        3       0         0       1  11206
# 5999          2.19    2      1        3       0         0       1  30507
#
# [6000 rows x 8 columns]

# %%
y = dr['Price'] #Output
X = dr.drop('Price',axis=1)
X
# Out:
#       Carat Weight  Cut  Color  Clarity  Polish  Symmetry  Report
# 0             1.10    2      4        2       3         0       1
# 1             0.83    2      4        3       2         2       0
# 2             0.85    2      4        2       0         0       1
# 3             0.91    2      1        2       3         3       1
# 4             0.83    2      3        2       0         0       1
# ...            ...  ...    ...      ...     ...       ...     ...
# 5995          1.03    2      0        2       0         0       1
# 5996          1.00    4      0        2       3         3       1
# 5997          1.02    2      0        2       0         0       1
# 5998          1.27    3      3        3       0         0       1
# 5999          2.19    2      1        3       0         0       1
#
# [6000 rows x 7 columns]

# %%
from sklearn.model_selection import  train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)

# %% [markdown]
# Q3)Using Linear Regression,Decison Tree Random Forest,XGBoost, Light GBM and Gradient Boosting Classifier with default parameters (no parameter specifications except random_state) calculate R2 statistics on test data. Which method gives the best accuracy on test data

# %%
def evalmetric(y,ypred):
 import numpy as np
 e = y - ypred 
 mse_f = np.mean(e**2)
 rmse_f = np.sqrt(mse_f)
 mae_f = np.mean(abs(e))
 mape_f = 100*np.mean(abs(e/y))
 r2_f = 1-(sum(e**2)/sum((y-np.mean(y))**2))
 print("MSE:", mse_f)
 print("RMSE:", rmse_f)
 print("MAE:",mae_f)
 print("MAPE:",mape_f)
 print("R-Squared:", r2_f)

# %%
#Q3
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor(random_state=17)
dtr.fit(X_train,y_train)
print('Test Data')
y_pred2 = dtr.predict(X_test)
evalmetric(y_test,y_pred2)
# Out:
# Test Data
# MSE: 0.12580730779439087
# RMSE: 0.3546932587382947
# MAE: 0.12580730779439087
# MAPE: inf
# R-Squared: -0.19697130149319086

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(random_state=17)
rfr.fit(X_train,y_train)
print('Test Data')
y_pred2 = rfr.predict(X_test)
evalmetric(y_test,y_pred2)
# Out:
# Test Data
# MSE: 0.06587092807219332
# RMSE: 0.25665332273748825
# MAE: 0.13060514907546258
# MAPE: inf
# R-Squared: 0.37328274575276343

# %%
from sklearn.ensemble import GradientBoostingRegressor
from time import time

gbr = GradientBoostingRegressor(random_state=17)
gbr.fit(X_train, y_train)
print('Test Data')
y_pred2 = gbr.predict(X_test)
evalmetric(y_test,y_pred2)
# Out:
# Test Data
# MSE: 0.0670490451485373
# RMSE: 0.258938303749247
# MAE: 0.14377846540783795
# MAPE: inf
# R-Squared: 0.36207375992431323

# %%
from xgboost import XGBRegressor
xgr = XGBRegressor(random_state=17)
xgr.fit(X_train, y_train)
print('Test Data')
y_pred2 = xgr.predict(X_test)
evalmetric(y_test,y_pred2)
# Out:
# [20:51:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Test Data
# MSE: 0.06722370956806947
# RMSE: 0.2592753547255687
# MAE: 0.14392879420726118
# MAPE: inf
# R-Squared: 0.3604119463044425

# %%
from time import time
import lightgbm as lgb
t0 = time()
lgr = lgb.LGBMRegressor(random_state=17)
lgr.fit(X_train, y_train)
print('Test Data')
y_pred2 = lgr.predict(X_test)
evalmetric(y_test,y_pred2)
# Out:
# Test Data
# MSE: 0.062419598247952734
# RMSE: 0.2498391447470807
# MAE: 0.12781643296257153
# MAPE: inf
# R-Squared: 0.4061198108170212

# %%
import sklearn.linear_model as skl_lm
regr = skl_lm.LinearRegression()
regr.fit(X_train,y_train)
print('Test Data')
y_pred2 = regr.predict(X_test)
evalmetric(y_test,y_pred2)
# Out:
# Test Data
# MSE: 0.08380391148731696
# RMSE: 0.2894890524481314
# MAE: 0.181522140445233
# MAPE: inf
# R-Squared: 0.20266255782904263

# %% [markdown]
# Light GBM with r^2 0.9812609895578275

# %% [markdown]
# Q4) Using optuna hyperparmeter optimization technique (100 trial) with Random Forest,XGBoost, Light GBM and Gradient Boosting Regressor
#
# a)find best methods with parameters using Cross validation (CV=3) technique for the range of parameters below. What are the best parameters for the method with highest cross validation R2?
#
# "max_depth": range(2, 7), "max_features": range(2, 7)
#
#
# b)Evaluate the performance of the method with highest cross validation R2 on test data. What is the R2 value?

# %%
import optuna

import sklearn.datasets
import sklearn.ensemble
import sklearn.model_selection
import sklearn.svm


# FYI: Objective functions can take additional arguments
# (https://optuna.readthedocs.io/en/stable/faq.html#objective-func-additional-args).
def objective(trial):
    x, y = X_train,y_train

    regressor_name = trial.suggest_categorical("regressor", ["GradientBoosting", "XGBoost","LightGBM","RandomForest"])
    if regressor_name == "GradientBoosting":
         max_depth = trial.suggest_int("max_depth", 2,7)
         max_features = trial.suggest_int("max_features", 2,7)
         regressor_obj = sklearn.ensemble.GradientBoostingRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
    
    elif regressor_name == "XGBoost":
         from xgboost import XGBRegressor
         max_depth = trial.suggest_int("max_depth", 2,7)
         max_features = trial.suggest_int("max_features", 2,7)
         regressor_obj = XGBRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
        
         

    elif regressor_name == "LightGBM":
         import lightgbm as lgb
         max_depth = trial.suggest_int("max_depth", 2,7)
         max_features = trial.suggest_int("max_features", 2,7)
         regressor_obj = lgb.LGBMRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
        
       
   
    else:
         max_depth = trial.suggest_int("max_depth", 2,7)
         max_features = trial.suggest_int("max_features", 2,7)
         regressor_obj = sklearn.ensemble.RandomForestRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )

     

    r2=sklearn.model_selection.cross_val_score(regressor_obj, x, y, n_jobs=-1, cv=3).mean()
   
    return r2


if __name__ == "__main__":
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=100)
    print(study.best_trial)
# Out:
# [I 2022-03-27 20:52:32,259] A new study created in memory with name: no-name-711ec688-5a82-4067-8e79-54e55c668d80
# [I 2022-03-27 20:52:34,988] Trial 0 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 4}. Best is trial 0 with value: 0.3837451601243402.
# [I 2022-03-27 20:52:35,953] Trial 1 finished with value: 0.3730531377754717 and parameters: {'regressor': 'LightGBM', 'max_depth': 4, 'max_features': 7}. Best is trial 0 with value: 0.3837451601243402.
# [I 2022-03-27 20:52:44,772] Trial 2 finished with value: 0.3722141260506455 and parameters: {'regressor': 'XGBoost', 'max_depth': 7, 'max_features': 6}. Best is trial 0 with value: 0.3837451601243402.
# [I 2022-03-27 20:52:48,440] Trial 3 finished with value: 0.363291800345327 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 4, 'max_features': 5}. Best is trial 0 with value: 0.3837451601243402.
# [I 2022-03-27 20:52:50,662] Trial 4 finished with value: 0.25366314050331984 and parameters: {'regressor': 'RandomForest', 'max_depth': 6, 'max_features': 2}. Best is trial 0 with value: 0.3837451601243402.
# [I 2022-03-27 20:52:55,108] Trial 5 finished with value: 0.37436187523109093 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 6, 'max_features': 4}. Best is trial 0 with value: 0.3837451601243402.
# [I 2022-03-27 20:52:57,990] Trial 6 finished with value: 0.32754799653604666 and parameters: {'regressor': 'XGBoost', 'max_depth': 2, 'max_features': 6}. Best is trial 0 with value: 0.3837451601243402.
# [I 2022-03-27 20:53:00,810] Trial 7 finished with value: 0.32754799653604666 and parameters: {'regressor': 'XGBoost', 'max_depth': 2, 'max_features': 3}. Best is trial 0 with value: 0.3837451601243402.
# [I 2022-03-27 20:53:02,828] Trial 8 finished with value: 0.1802966950069401 and parameters: {'regressor': 'RandomForest', 'max_depth': 2, 'max_features': 6}. Best is trial 0 with value: 0.3837451601243402.
# [I 2022-03-27 20:53:11,619] Trial 9 finished with value: 0.3722141260506455 and parameters: {'regressor': 'XGBoost', 'max_depth': 7, 'max_features': 5}. Best is trial 0 with value: 0.3837451601243402.
# [I 2022-03-27 20:53:12,731] Trial 10 finished with value: 0.38119356678276883 and parameters: {'regressor': 'LightGBM', 'max_depth': 5, 'max_features': 3}. Best is trial 0 with value: 0.3837451601243402.
# [I 2022-03-27 20:53:13,831] Trial 11 finished with value: 0.38119356678276883 and parameters: {'regressor': 'LightGBM', 'max_depth': 5, 'max_features': 3}. Best is trial 0 with value: 0.3837451601243402.
# [I 2022-03-27 20:53:14,937] Trial 12 finished with value: 0.38119356678276883 and parameters: {'regressor': 'LightGBM', 'max_depth': 5, 'max_features': 3}. Best is trial 0 with value: 0.3837451601243402.
# [I 2022-03-27 20:53:16,122] Trial 13 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 4}. Best is trial 0 with value: 0.3837451601243402.
# [I 2022-03-27 20:53:17,303] Trial 14 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 4}. Best is trial 0 with value: 0.3837451601243402.
# [I 2022-03-27 20:53:18,516] Trial 15 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 4}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:19,707] Trial 16 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:20,906] Trial 17 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:22,476] Trial 18 finished with value: 0.3270148512371537 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 3, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:25,002] Trial 19 finished with value: 0.27613614384347857 and parameters: {'regressor': 'RandomForest', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:26,207] Trial 20 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:27,420] Trial 21 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:28,631] Trial 22 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:29,800] Trial 23 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 3}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:30,991] Trial 24 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:32,160] Trial 25 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 3}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:33,364] Trial 26 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:35,787] Trial 27 finished with value: 0.35202941421888223 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:37,561] Trial 28 finished with value: 0.18715226670033025 and parameters: {'regressor': 'RandomForest', 'max_depth': 3, 'max_features': 3}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:38,755] Trial 29 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:39,936] Trial 30 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 3}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:41,114] Trial 31 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 5}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:42,305] Trial 32 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:43,485] Trial 33 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 3}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:44,670] Trial 34 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 5}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:45,856] Trial 35 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:53,122] Trial 36 finished with value: 0.3763815414974146 and parameters: {'regressor': 'XGBoost', 'max_depth': 6, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:57,347] Trial 37 finished with value: 0.36595663336911777 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 4, 'max_features': 6}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:53:58,546] Trial 38 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 5}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:06,460] Trial 39 finished with value: 0.3763815414974146 and parameters: {'regressor': 'XGBoost', 'max_depth': 6, 'max_features': 5}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:09,410] Trial 40 finished with value: 0.24664452787349 and parameters: {'regressor': 'RandomForest', 'max_depth': 3, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:10,598] Trial 41 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:11,797] Trial 42 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 6}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:13,002] Trial 43 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:14,179] Trial 44 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 5}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:15,385] Trial 45 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 4}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:22,543] Trial 46 finished with value: 0.37610349989645747 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 7, 'max_features': 6}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:23,777] Trial 47 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 3}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:32,718] Trial 48 finished with value: 0.3722141260506455 and parameters: {'regressor': 'XGBoost', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:34,737] Trial 49 finished with value: 0.22443057815469505 and parameters: {'regressor': 'RandomForest', 'max_depth': 5, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:35,848] Trial 50 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:37,062] Trial 51 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:38,280] Trial 52 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:39,487] Trial 53 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 3}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:40,682] Trial 54 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:41,884] Trial 55 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:43,079] Trial 56 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 3}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:44,280] Trial 57 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 5}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:45,494] Trial 58 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 4}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:46,662] Trial 59 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 4}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:52,775] Trial 60 finished with value: 0.3798527675373721 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 7, 'max_features': 5}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:53,967] Trial 61 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 3}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:55,166] Trial 62 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:56,375] Trial 63 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:57,587] Trial 64 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:54:58,798] Trial 65 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 6}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:07,544] Trial 66 finished with value: 0.3722141260506455 and parameters: {'regressor': 'XGBoost', 'max_depth': 7, 'max_features': 5}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:08,255] Trial 67 finished with value: 0.3285509525098687 and parameters: {'regressor': 'LightGBM', 'max_depth': 2, 'max_features': 6}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:12,676] Trial 68 finished with value: 0.32433175003476394 and parameters: {'regressor': 'RandomForest', 'max_depth': 6, 'max_features': 6}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:13,874] Trial 69 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 6}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:15,048] Trial 70 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 5}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:16,263] Trial 71 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 6}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:17,466] Trial 72 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 5}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:18,679] Trial 73 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:19,870] Trial 74 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:20,826] Trial 75 finished with value: 0.3730531377754717 and parameters: {'regressor': 'LightGBM', 'max_depth': 4, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:22,030] Trial 76 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:23,202] Trial 77 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:26,417] Trial 78 finished with value: 0.3646632559791887 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:33,790] Trial 79 finished with value: 0.3763815414974146 and parameters: {'regressor': 'XGBoost', 'max_depth': 6, 'max_features': 3}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:34,990] Trial 80 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 4}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:36,210] Trial 81 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:37,423] Trial 82 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:38,656] Trial 83 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:39,858] Trial 84 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:41,061] Trial 85 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:47,865] Trial 86 finished with value: 0.3384202626851655 and parameters: {'regressor': 'RandomForest', 'max_depth': 7, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:48,683] Trial 87 finished with value: 0.359339894831263 and parameters: {'regressor': 'LightGBM', 'max_depth': 3, 'max_features': 4}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:49,845] Trial 88 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 3}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:51,033] Trial 89 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 3}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:52,212] Trial 90 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 3}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:53,428] Trial 91 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 4}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:54,622] Trial 92 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 2}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:55,815] Trial 93 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:57,015] Trial 94 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:58,231] Trial 95 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 7}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:55:59,435] Trial 96 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 6}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:56:06,492] Trial 97 finished with value: 0.37610349989645747 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 7, 'max_features': 6}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:56:07,601] Trial 98 finished with value: 0.38119356678276883 and parameters: {'regressor': 'LightGBM', 'max_depth': 5, 'max_features': 5}. Best is trial 15 with value: 0.38671654769148894.
# [I 2022-03-27 20:56:08,794] Trial 99 finished with value: 0.38671654769148894 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 5}. Best is trial 15 with value: 0.38671654769148894.
# FrozenTrial(number=15, values=[0.38671654769148894], datetime_start=datetime.datetime(2022, 3, 27, 20, 53, 17, 305459), datetime_complete=datetime.datetime(2022, 3, 27, 20, 53, 18, 515724), params={'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 4}, distributions={'regressor': CategoricalDistribution(choices=('GradientBoosting', 'XGBoost', 'LightGBM', 'RandomForest')), 'max_depth': IntUniformDistribution(high=7, low=2, step=1), 'max_features': IntUniformDistribution(high=7, low=2, step=1)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=15, state=TrialState.COMPLETE, value=None)

# %%
print(study.best_params)
# Out:
# {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 4}

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)
from sklearn.ensemble import GradientBoostingRegressor
from time import time

gbr = GradientBoostingRegressor(random_state=17,max_depth= 5,max_features= 6)
gbr.fit(X_train,y_train)
print('Test Data')
y_pred2 = gbr.predict(X_test)
evalmetric(y_test,y_pred2)
# Out:
# Test Data
# MSE: 0.06445863733901684
# RMSE: 0.2538870562652158
# MAE: 0.13698748413866152
# MAPE: inf
# R-Squared: 0.3867197352775674

# %% [markdown]
# R^2 value is 0.985108420764872
